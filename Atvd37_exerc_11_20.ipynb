# %% [markdown]
# <a href="https://colab.research.google.com/github/brunodeoliveira-byte/atividade_iespes/blob/main/Atvd37_exerc_11_20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
aluno = input("Informe o Nome do Aluno: ")
nota01 = float(input("Nota da Primeira Avaliação: "))
nota02 = float(input("Nota da Segunda Avaliação: "))
nota03 = float(input("Nota das Atividades: "))
nota04 = float(input("Nota de Participação em Eventos e Extensão: "))
media = ((nota01+nota02+nota03+nota04)/4)
if media >=7:
  situacao = "Aprovado"
else:
  situacao = "Reprovado"
print(f"{aluno} {situacao}")
# Out:
# Informe o Nome do Aluno: Bruno
# Nota da Primeira Avaliação: 5
# Nota da Segunda Avaliação: 4.3
# Nota das Atividades: 7.8
# Nota de Participação em Eventos e Extensão: 5.1
# Bruno Reprovado

# %% [markdown]
# 20.Desenvolva um sistema que classifique um aluno como aprovado ou reprovado
# (média ≥ 7)

# %%
nome = input("Informe Seu Nome: ")
nascimento = int(input("Informe o Ano do Seu Nascimento: "))
ano_atual = int(input("Informe o Ano Atual: "))
idade = ano_atual - nascimento
if idade >= 18:
  situacao = "Você tem Permissão para Entrar!"
elif 13 <= idade <= 17:
  situacao = "Apresente o Documento de Autorização do Responsável!"
else:
  situacao = "Informamos que não permitimos a entrada de Crianças!"
print (f"{nome}, {situacao}")
# Out:
# Informe Seu Nome: Bruno
# Informe o Ano do Seu Nascimento: 2016
# Informe o Ano Atual: 2026
# Bruno, Informamos que não permitimos a entrada de Crianças!

# %% [markdown]
# 19.Crie um programa que verifique se uma pessoa é maior de idade.

# %%
area = float(input("Informe o tamanho da área (se não souber digite 0): "))
base = float(input("Informe o tamanho da base (se não souber digite 0): "))
altura = float(input("Informe o tamanho da altura (se não souber digite 0): "))

if area == 0 and base != 0 and altura != 0:
  area = base * altura
  print(f"O tamanho da área é {area} metros")
elif base == 0 and area != 0 and altura != 0:
  base = area / altura
  print(f"O tamanho da base é {base} metros")
elif altura == 0 and area != 0 and base != 0:
 altura = area / base
 print(f"O tamanho da altura é {altura} metros")
else:
  print("Resultado Inválido. Informe pelo menos dois valores!")
# Out:
# Informe o tamanho da área (se não souber digite 0): 0
# Informe o tamanho da base (se não souber digite 0): 0
# Informe o tamanho da altura (se não souber digite 0): 15
# Resultado Inválido. Informe pelo menos dois valores!

# %% [markdown]
# 18.Desenvolva um programa que calcule a área de um retângulo.

# %%
valor_conta = float(input("Informe o valor da Conta: R$ "))
taxa_servico = float(input("Informe a taxa de serviço(%): "))
valor_taxa = valor_conta * (taxa_servico / 100)
valor_final = valor_conta + valor_taxa

print(f"Valor da Taxa de Serviço é:R$ {valor_taxa}")
print(f"Valor Final para pagar: R$ {valor_final}")
# Out:
# Informe o valor da Conta: R$ 200
# Informe a taxa de serviço(%): 10
# Valor da Taxa de Serviço é:R$ 20.0
# Valor Final para pagar: R$ 220.0

# %% [markdown]
# 17.Faça um programa que calcule o valor final de uma conta com taxa de serviço.

# %%
produto = input("Informe o nome do produto: ")
preco_produto = float(input("Informe o preço do produto:R$ "))
taxa_desconto = float(input("Informe a taxa de desconto(%): "))
valor_desconto = (preco_produto * (taxa_desconto / 100))
valor_final = preco_produto - valor_desconto
print(f"Você pagará pelo prouto comprado o valor de R$ {valor_final}")
# Out:
# Informe o nome do produto: camisa
# Informe o preço do produto:R$ 100
# Informe a taxa de desconto(%): 10
# Você pagará pelo prouto comprado o valor de R$ 90.0

# %% [markdown]
# 16.Crie um programa que calcule o valor de desconto de um produto (ex: 20%).

# %%
distancia = float(input("Informe a distância percorrida (km): "))
combustivel = float(input("Informe a quantidade de combustível usada(L): "))
consumo_medio = distancia / combustivel

print(f"O consumo médio foi de {consumo_medio}km/L")
# Out:
# Informe a distância percorrida (km): 50
# Informe a quantidade de combustível usada(L): 10
# O consumo médio foi de 5.0km/L

# %% [markdown]
# 15.Desenvolva um programa que calcule o consumo médio de combustível (km/l).

# %%
ano_nascimento = int(input("Informe o ano que você nasceu: "))
ano_atual = int(input("Informe o ano atual: "))
idade = ano_atual - ano_nascimento

print(f"Sua idade é {idade} anos")
# Out:
# Informe o ano que você nasceu: 1987
# Informe o ano atual: 2026
# Sua idade é 39

# %% [markdown]
# 14.Desenvolva um programa que calcule a idade de uma pessoa com base no ano de
# nascimento.

# %%
produto = input("Informe o nome do produto: ")
preco_unitario = float(input("Informe o preço do produto:R$ "))
quantidade = float(input("Informe a quantidade que será comprada: "))
valor_total = preco_unitario * quantidade

print(f"O valor total da sua compra é de R$ {valor_total}")
# Out:
# Informe o nome do produto: Queijo
# Informe o preço do produto:R$ 20.50
# Informe a quantidade que será comprada: 10
# O valor total da sua compra é de R$ 205.0

# %% [markdown]
# 13.Faça um programa que calcule o valor total de uma compra (quantidade × preço).

# %%
salario = float(input("Informe o valor da sua renda:R$ "))
bonus = float(input("Bônus Adicional(%): "))
valor_bonus = (salario * (bonus /100))
salario_final = salario + valor_bonus

print(f"Parabéns, você foi contemplado com um bônus adicional de {bonus}%, o valor final de seu salário é de R$ {salario_final}")
# Out:
# Informe o valor da sua renda:R$ 1500
# Bônus Adicional(%): 5
# Parabéns, você foi contemplado com um bônus adicional de 5.0%,o valor final de seu salário é de R$ {salario_final}

# %% [markdown]
# 12. Crie um programa que calcule o salário com bônus de 10%.

# %%
aluno = input("Informe o nome do aluno: ")
nota01 = float(input("Informe a primeira nota: "))
nota02 = float(input("Informe a segunda nota: "))
media = (nota01 + nota02)/2

print(f"{aluno} sua nota final alcançou a seguinte média {media}")
# Out:
# Informe o nome do aluno: Bruno
# Informe a primeira nota: 9.7
# Informe a segunda nota: 7.8
# Bruno sua nota final alcançou a seguinte média 8.75

# %% [markdown]
# 11. Desenvolva um programa que calcule a média de duas notas de um aluno.
