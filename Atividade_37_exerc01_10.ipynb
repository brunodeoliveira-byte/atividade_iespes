# %% [markdown]
# <a href="https://colab.research.google.com/github/brunodeoliveira-byte/atividade_iespes/blob/main/Atividade_37_exerc01_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#10. Faça um programa que receba o nome de uma cidade e exiba uma mensagem com ela.#

cidade = input("Informe o nome de uma cidade: ")
print(f"Conheça as Belezas e os Encantos de {cidade}")
# Out:
# Informe o nome de uma cidade: santarém
# Conheça as Belezas e os Encantos de santarém

# %%
#9.Crie um programa que receba a altura e o peso de uma pessoa#

nome = input("Informe seu nome: ")
altura = float(input("Informe sua altura: "))
peso = float(input("Informe seu peso: "))
print(f"{nome}, sua altura corresponde a {altura} e seu peso está em {peso} kg")
# Out:
# Informe seu nome: bruno
# Informe sua altura: 162
# Informe seu peso: 58
# bruno, sua altura corresponde a 162.0 e seu peso está em 58.0 kg

# %%
#8.Desenvolva um programa que receba o salário de um funcionário.#

funcionario = input("Informe o nome do Funcionário: ")
salario = float(input("Informe o salário do funcionário: R$ "))
print(f"O funcionário {funcionario} ganha aproximadamente R$ {salario}")
# Out:
# Informe o nome do Funcionário: buno
# Informe o salário do funcionário: R$ 1500
# O funcionário buno ganha aproximadamente R$ 1500.0

# %%
#7.Faça um programa que receba o nome de um produto e seu preço.#

produto = input("Informe o nome do Produto: ")
preco_produto = float(input("Informe o preço do produto: R$ "))
print(f"{produto} custa R$ {preco_produto}")
# Out:
# Informe o nome do Produto: queijo
# Informe o preço do produto: R$ 20.00
# queijo custa R$ 20.0

# %%
#6.Crie um programa que receba um valor em reais e exiba esse valor com mensagem formatada.#

# %%
#5.Desenvolva um programa que receba dois números e exiba a soma entre eles.#

elemento01 = int(input("Atribua um Valor Numérico qualquer para elemento01: "))
elemento02 = int(input("Atribua um Valor Numérico qualquer para elemento02: "))
resultado = elemento01 + elemento02
print (f"A soma dos valores informados correponde a {resultado}")
# Out:
# Atribua um Valor Numérico qualquer para elemento01: 100
# Atribua um Valor Numérico qualquer para elemento02: 100
# A soma dos valores informados correponde a 200

# %%
#4. Faça um programa que receba um número inteiro e exiba seu dobro.#

numero = int(input("Informe um Número Qualquer: "))
resultado = numero * 2
print(f"O dobro do número digitado corresponde a {resultado}")
# Out:
# Informe um Número Qualquer: 100
# O dobro do número digitado corresponde a 200

# %%
#3.Crie um programa que receba o nome e o curso de um aluno e exiba ambos organizadamente.#

nome = input("Informe Seu Nome: ")
curso = input("Informe o nome do Curso:  ")
print(f"{nome}, você está participando das aulas do curso de {curso}")
# Out:
# Informe Seu Nome: bruno
# Informe o nome do Curso:  rede computdores
# bruno, você está participando das aulas do curso de rede computdores

# %% [markdown]
# 3. Crie um programa que receba o nome e o curso de um aluno e exiba ambos
# organizadamente.

# %%
ano_nascimento = int(input("Informe o ano de seu Nascimento: "))
ano_atual = int(input("Informe o ano atual: "))
idade = ano_atual - ano_nascimento
print (f"Você tem {idade} anos")
# Out:
# Informe o ano de seu Nascimento: 1987
# Informe o ano atual: 2026
# Você tem 39 anos

# %% [markdown]
# 2. Desenvolva um programa que receba a idade de uma pessoa e exiba essa
# informação na tela.

# %%
nome = input("Informe Seu Nome: ")
print (f"{nome}, Obrigado pela Preferência! Sua Presença e suas Atividades, são importantes para  o SISTEMA!")
# Out:
# Informe Seu Nome: bruno
# bruno, Obrigado pela Preferência! Sua Presença e suas Atividades, são importantes para  o SISTEMA!

# %% [markdown]
# 1) Crie um programa que receba o nome do usuário e exiba uma mensagem de
# boas-vindas personalizada.
