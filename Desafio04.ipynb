# %% [markdown]
# <a href="https://colab.research.google.com/github/brunodeoliveira-byte/atividade_iespes/blob/main/Desafio04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Protocolo De Avaliação Ambiental em Ambiente Urbano: Praça Pública#

print("Protocolo de Avalição do Espaço Urbano: Praça Pública")
nome = input("Identificação do Local(Nome): ")
localizacao = input("Endereço(Bairro): ")

pontuacao = 0
#INFRAETRTURA#
lixeiras =input("1) Presença de lixeiras (sim/não): ").lower()
if lixeiras == "sim" or lixeiras == "S":
  pontuacao += 2

condicao_lixeiras = input("2) Presença de lixeiras em boas condições (sim/não): ").lower()
if condicao_lixeiras == "sim" or condicao_lixeiras == "S":
  pontuacao += 2

lixeira_seletiva = input("3) Presença de lixeiras seletivas (sim/não): ").lower()
if lixeira_seletiva == "sim" or lixeira_seletiva == "S":
  pontuacao +=2

ecoponto = input("4) Presença de ecoponto (sim/não): ").lower()
if ecoponto == "sim" or ecoponto == "S":
  pontuacao += 2

placa = input("5) Presença de placa informativa (sim/não): ").lower()
if placa == "sim"or placa == "S":
    pontuacao += 2

#SITUAÇÃO SANITÁRIA#
residuo_chao = input("6) Ocorrência de resíduo no chão (sim/não): ").lower()
if residuo_chao == "não" or residuo_chao == "N":
  pontuacao += 2

tipo_residuo = input("7) Tipo de resíduo (metal; orgânico; papel/papelão; plástico; vidro): ").lower()
if tipo_residuo == "orgânico":
  pontuacao += 2
else:
  pontuacao += 1

presenca_praga = input("8) Há ocorrência de pragas (sim/não): ").lower()
if presenca_praga == "não" or presenca_praga == "N":
  pontuacao += 3
else:
  tipo_praga = input("9) O tipo de praga com maior ocorrência (baratas; formigas; moscas; mosquitos; pombos): ").lower()

agua_cinza = input("10) Há ocorrência de despejo de água cinza a céu aberto (sim/não): ").lower()
if agua_cinza == "nao" or agua_cinza == "N":
  pontuacao += 3

odor = input("11) Há ocorrência de mal cheiro (sim/não): ").lower()
if odor == "não" or odor == "N":
  pontuacao += 2

#CONDIÇÃO DO AMBIENTE#
estado_vegetacao = input("12) Estado da vegetação/jardinagem (Boa; Regular: Ruim): ").lower()
if estado_vegetacao == "Boa":
  pontuacao += 2
elif estado_vegetacao == "Regular":
  pontuacao += 1

poluicao_sonora = input("13) A percepção sonora é considerada (Agradável; Desagradável)").lower()
if poluicao_sonora == "Agradável":
  pontuacao += 2

poluicao_visual = input("14) A percepção visual é considerada (Agradável; Desagradável): ").lower()
if poluicao_visual == "Agradável":
  pontuacao += 2

limpeza_local = input("15) A limpeza do local é considerada (Boa; Regular; Ruim): ").lower()
if limpeza_local == "Boa":
  pontuacao += 2
elif limpeza_local == "Regular":
  pontuacao += 1

responsavel_limpeza = input("16) Responsável pela limpeza do local (Comunitários ou Empreendedores que Utilizam o Espaço; Serviço Público; Ninguém): ").lower()
if responsavel_limpeza == "Serviço Público" or responsavel_limpeza == "SP":
  pontuacao += 2
elif responsavel_limpeza == "Comunitários ou Empreendedores que Utilizam o Espaço" or responsavel_limpeza == "CEUE":
  pontuacao += 1

periodicidade_limpeza = input("17) Periodiciade da limpeza do local (Todo Dia; 2/3 vezes na Semana; 1 vez na Semana): ")
if periodicidade_limpeza == "Todo Dia" or periodicidade_limpeza == "TD":
  pontuacao += 2
elif periodicidade_limpeza == "2/3 vezes na Semana" or periodicidade_limpeza == "2/3S":
  pontuacao += 1
else:
  pontuacao -= 1

#RESULTADO#
max_pontuacao = 36
porcentagem = (pontuacao/max_pontuacao)*100

if pontuacao >= 26:
  calssificacao = "BOA"
elif pontuacao >= 15:
  classificacao = "REGULAR"
else:
  classificacao = "CRÍTICA"

print("==#== RESULTADO ==#==")
print(f"Pontuacao {pontuacao}")
print(f"Qualidade {porcentagem}%")
print(f"Classificação {classificacao}")
# Out:
# Protocolo de Avalição do Espaço Urbano: Praça Pública
# Identificação do Local(Nome): Praça Tiradentes
# Endereço(Bairro): Av.Tapajós - Aldeia
