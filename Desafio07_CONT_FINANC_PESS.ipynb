# %% [markdown]
# <a href="https://colab.research.google.com/github/brunodeoliveira-byte/atividade_iespes/blob/main/Desafio07_CONT_FINANC_PESS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# SISTEMA DE CONTROLE FINANCEIRO PESSOAL #

print("\n #====== CONTROLE FINANCEIRO PESSOAL ======#")

# ====== RENDA ====== #
print("\n #====== RENDA ======#")
renda_principal = float(input("Informe o valor da sua renda principal: R$ "))
renda_extra = float(input("Se você possui alguma renda extra informe o valor: R$ "))
renda_total = renda_principal + renda_extra
print(f"Sua Renda Total é: R${renda_total}")

# ====== DESPESAS FIXAS ====== #
print("\n #====== DESPESAS FIXAS ======#")
luz = float(input("Informe o valor da sua conta de luz: R$ "))
agua = float(input("Informe o valor da sua conta de água: R$ "))
transporte = float(input("Informe o valor que você paga em transporte: R$ "))
internet = float(input("Informe o valor da sua conta de internet: R$ "))
supermercado = float(input("Informe o valor médio que você paga em supermercado: R$ "))
academia = float(input("Informe o valor da mensalidade da academia: R$ "))
farmacia = float(input("Informe o valor médio que você paga em farmácia: R$ "))

despesas_fixas = luz + agua + transporte + internet + supermercado + academia + farmacia
print(f"O total de suas despesas fixas é: R$ {despesas_fixas}")

# ====== DESPESAS VARIÁVEIS ====== #
print("\n #====== DESPESAS VARIADAS ======#")
gas = float(input("Informe o valor que você usou esse mês na compra de gás: R$ "))
vestuario = float(input("Informe o valor que você usou esse mês com vestuário: R$ "))
educacao = float(input("Informe o valor que você usou esse mês com estudo: R$ "))
lazer = float(input("Informe o valor que você usou esse mês com lazer: R$ "))
saude = float(input("Informe o valor que você usou esse mês com consultas, exames ou dentista: R$ "))

despesas_variadas = gas + vestuario + educacao + lazer + saude
print(f"O total de suas despesas variadas é: R$ {despesas_variadas}")


print("\n #====== DESPESAS ESPECIAIS ======#")
presente = float(input("Informe o valor que você usou esse mês para comprar algum presente: R$ "))
consertos = float(input("Informe o valor que você usou esse mês para fazer algum reparo doméstico: R$ "))
emergencia = float(input("Informe o valor que você usou esse mês com alguma despesa não prevista: R$ "))

despesas_especiais = presente + consertos + emergencia
print(f"O total de suas despesas especiais é: R$ {despesas_especiais}")

print("\n #====== ECONOMIA ======# ")

poupanca = float(input("Informe o valor que você tem em depósito: R$ "))
deposito = float(input("Informe o valor destinado para depósito: R$ "))
atualizacao = poupanca + deposito
print(f"Atualização da poupança: R$ {atualizacao}")

print("\n #====== CÁLCULO ======# ")

despesa_total = despesas_fixas + despesas_variadas + despesas_especiais
print(f"O toltal de suas despesas alcançaram o valor de: R$ {despesa_total}")
saldo_final = renda_total - despesa_total
print(f"O seu saldo é de: R$ {saldo_final}")

if renda_total > 0:
  taxa_economia = (deposito / renda_total)*100
  taxa_despesa = (despesa_total / renda_total)*100
else:
  taxa_economia = 0
  taxa_despesa = 0

#====== CLASSIFICAÇÃO ======#

if saldo_final < 0:
  classificacao = "PONTO CRÍTICO: VOCÊ ESTÁ GASTANDO MAIS DO QUE GANHA!"
elif taxa_economia < 10:
  classificacao = "ATENÇÃO: SUA TAXA DE ECONOMIA ESTÁ MUITO BAIXA!"
elif taxa_economia < 20:
  classificacao = "SITUAÇÃO BOA: MESMO COM DESAFIOS VOCÊ ESTÁ CONSEGUINDO ECONOMIZAR!"
else:
  classificacao = "SITUAÇÃO ÓTIMA: EXCELENTE CONTROLE FINANCEIRO!"

print("\n #====== RELATÓRIO ======# ")

print(f"Taxa de Economia(%): {taxa_economia}")
print(f"Taxa de Despesas (%): {taxa_despesa}")

if saldo_final < 0:
  print("REVEJA SEUS GASTOS: SUAS DESPESAS UTLTRAPASSAM SUA RENDA!!")

if taxa_economia < 10:
  print("SUA DIFICULDADE PARA ECONOMIZAR É PREOCUPANTE!!")
elif taxa_economia < 20:
  print("SUA CAPACIDADE DE ECONOMIZAR É BOA, MAS PODE MELHORAR!!")
else:
  print("SUA CAPACIDADE DE ECONOMIZAR É EXCELENTE!!")

if lazer > (renda_total *0.15):
  print("Seus gastos com LAZER estão elevados!!")

  if despesas_especiais > 0:
    print("DESPESAS IMPREVISTAS OCORREM")
    print("NINGUÉM ESTÁ LIVRE DO INEVITÁVEL!!")
    print("TER UMA RESERVA FINANCEIRA É FUNDAMENTAL PARA SITUAÇÕES FORA DO PLANO!!")
# Out:
#  #====== CONTROLE FINANCEIRO PESSOAL ======#
#
#  #====== RENDA ======#
# Informe o valor da sua renda principal: R$ 2500
# Se você possui alguma renda extra informe o valor: R$ 0
# Sua Renda Total é: R$2500.0
#
#  #====== DESPESAS FIXAS ======#
# Informe o valor da sua conta de luz: R$ 145
# Informe o valor da sua conta de água: R$ 67
# Informe o valor que você paga em transporte: R$ 170
# Informe o valor da sua conta de internet: R$ 130
# Informe o valor médio que você paga em supermercado: R$ 670
# Informe o valor da mensalidade da academia: R$ 120
# Informe o valor médio que você paga em farmácia: R$ 140
# O total de suas despesas fixas é: R$ 1442.0
#
#  #====== DESPESAS VARIADAS ======#
# Informe o valor que você usou esse mês na compra de gás: R$ 0
# Informe o valor que você usou esse mês com vestuário: R$ 100
# Informe o valor que você usou esse mês com estudo: R$ 160
# Informe o valor que você usou esse mês com lazer: R$ 170
# ...
