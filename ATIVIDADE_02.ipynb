# %% [markdown]
# <a href="https://colab.research.google.com/github/brunodeoliveira-byte/atividade_iespes/blob/main/ATIVIDADE_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#SISTEMA DE ATENDIMENTO#
#EM UNIDADE BÁSICA DE SAÚDE - UBS#

nome = input("Informe seu nome: ")
cartao_sus = input("Informe o número do Cartão SUS: ")
agente_saude = input("Informe o nome do(a) Agente de Saúde: ")

print("\nTipos de Atendimento:")
print("1.AL - Acidentes Leves")
print("2.SL - Sintomas Leves")
print("3.CST - Consulta")
print("4.ColEX - Coleta de Exame")
print("5.PN - Pré-Natal")
print("6.AI05 - Atendimento Infantil I (0 a 5 anos)")
print("7.AI0612 - Atendimento Infantil II 6 a 12 anos")
print("8.A1317 - Atendimento de Adolescentes 13 a 17 anos")
print("9.AJ1827 - Atendimento de Jovens 18 a 27 anos")
print("10.AA2859 - Atendimento de Adultos 28 a 59 anos")
print("11.AId60+ - Atendimento de Idosos 60 anos ou mais")
print("12.SSB01 - Serviço de Saúde Bucal 01")
print("13.SSB02 - Serviço de Saúde Bucal 02")
print("14.SSMG - Serviço de Saúde Mental Geral")
print("15.SSMId - Serviço de Saúde Mental Para Idosos")
print("16.SAdm - Serviço Administrativo")
print("17.V - Vacinação")

escolha = input("Código do Atendimento: ")

if escolha == "1.AL":
    print("Atendimento Imediato: Sala 01")

elif escolha == "2.SL":
    print("Atendimento Imediato: Sala 02")

elif escolha == "3.CST" or escolha == "4.ColEx":
    print(nome,"Atendimento Agendado para Quinta-feira das 8 às 14 horas! Por Ordem de Chegada!")

elif escolha == "5.PN" or escolha == "6.AI05" or escolha == "14.SSMG" or escolha == "17.V":
    print(nome,"Atendimento Agendado para Segunda-feira de 8 às 14 horas!Por Ordem de Chegada!")

elif escolha == "7.AI0612" or escolha == "8.AI1317" or escolha == "12.SSB01" or escolha == "17.V":
    print(nome,"Atendimento Agendado para Terça-feira de 8 às 14 horas! Por Ordem de Chegada!")

elif escolha == "9.AJ1827" or escolha == "10.AA2859" or escolha == "13.SSB02" or escolha == "17.V":
    print(nome,"Atendimento Agendado para Quarta-feira de 8 às 14 horas! Por Ordem de Chegada!")

elif escolha == "11.AI60+" or escolha == "15.SSMId" or escolha == "17,.":
    print(nome,"Atendimento Por Ordem de Chegada: Quinta-feira de 8 às 14 horas!")

else:
    print("Serviço Administrativo ou Ação Estratégica")
# Out:
# Informe seu nome: Amélia
# Informe o número do Cartão SUS: 1234
# Informe o nome do(a) Agente de Saúde: bruno
#
# Tipos de Atendimento:
# 1.AL - Acidentes Leves
# 2.SL - Sintomas Leves
# 3.CST - Consulta
# 4.ColEX - Coleta de Exame
# 5.PN - Pré-Natal
# 6.AI05 - Atendimento Infantil I (0 a 5 anos)
# 7.AI0612 - Atendimento Infantil II 6 a 12 anos
# 8.A1317 - Atendimento de Adolescentes 13 a 17 anos
# 9.AJ1827 - Atendimento de Jovens 18 a 27 anos
# 10.AA2859 - Atendimento de Adultos 28 a 59 anos
# 11.AId60+ - Atendimento de Idosos 60 anos ou mais
# 12.SSB01 - Serviço de Saúde Bucal 01
# 13.SSB02 - Serviço de Saúde Bucal 02
# 14.SSMG - Serviço de Saúde Mental Geral
# 15.SSMId - Serviço de Saúde Mental Para Idosos
# 16.SAdm - Serviço Administrativo
# 17.V - Vacinação
# Código do Atendimento: 2.SL
# Atendimento Imediato: Sala 02
